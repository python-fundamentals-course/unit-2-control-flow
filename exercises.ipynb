# %% [markdown]
# # Unit 2: Control Flow — Exercises
#
# > **Python Fundamentals**
#
# Complete the reading materials, curated videos, and `notebook.ipynb` before working through these exercises.

# %% [markdown]
# ## Learning objectives
#
# By the end of this unit you will be able to:
#
# - Write if/elif/else blocks for business decision logic
# - Apply for loops to filter, transform, and aggregate data
# - Decompose a business problem into control flow before writing code

# %% [markdown]
# ## Exercise 1: Temperature categorisation
#
# For each temperature in `temperatures`, classify it as:
#
# - `"cold"` if below 10
# - `"mild"` if 10 to 25 (inclusive)
# - `"hot"` if above 25
#
# Print each temperature with its category, e.g. `-5°C is cold`.

# %%
temperatures = [-5, 15, 30, 10, 25]

# TODO: loop over temperatures, classify each with if/elif/else,
# and print '<temp>°C is <category>'

# %% [markdown]
# ## Exercise 2: Loan eligibility
#
# For each applicant in `applicants`, decide their loan status:
#
# - `"approved"` if `income >= 3000` **and** `credit_score >= 650`
# - `"declined"` if `income < 1500` **or** `credit_score < 500`
# - `"manual review"` otherwise
#
# Print each applicant's name and status.

# %%
applicants = [
    {"name": "Alice", "income": 4000, "credit_score": 700},
    {"name": "Bob", "income": 1200, "credit_score": 480},
    {"name": "Carol", "income": 2500, "credit_score": 600},
]

# TODO: loop over applicants and print name + status

# %% [markdown]
# ## Exercise 3: Filter, transform, aggregate — daily steps
#
# Given a week of daily step counts in `steps`:
#
# 1. **Filter**: build a list of the days where steps were >= 10,000
# 2. **Transform**: build a list converting each day's steps to kilometres (`steps * 0.0008`)
# 3. **Aggregate**: calculate the total steps for the week
#
# Print all three results.

# %%
steps = [8500, 12000, 9800, 15200, 6000, 11000, 9000]

# TODO: 1. Filter - days with >= 10,000 steps


# TODO: 2. Transform - steps converted to km


# TODO: 3. Aggregate - total steps for the week

# %% [markdown]
# ## Exercise 4: Savings goal — while loop
#
# You start with a balance of **$500**. Each month:
#
# 1. You deposit **$150**
# 2. The bank then adds **0.5% interest** on the new balance
#
# Use a `while` loop to find out how many months it takes until your balance reaches at least **$2000**. Print the number of months and the final balance (rounded to 2 decimal places).

# %%
balance = 500
monthly_deposit = 150
interest_rate = 0.005
goal = 2000
months = 0

# TODO: while loop - deposit, then apply interest, then count the month


# TODO: print the number of months and the final balance

# %% [markdown]
# ## Done?
#
# Run the tests (`pytest tests/ -v`) to check whether your answer is correct. Your solution doesn't need to match any particular approach, as long as it produces the right results — your trainer can walk through worked solutions in class.
